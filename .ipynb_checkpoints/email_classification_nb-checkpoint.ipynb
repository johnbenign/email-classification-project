# %%
import pandas as pd

# %%
df_training = pd.read_csv("training_emails.csv")
df_test = pd.read_csv("test_emails.csv")
df_test.head()
#Label 1 = Spam, Label 0 = Ham
# Out:
#                                              Subject  \
# 0                            re : midcoast marketing
# 1                           samson lone star limited
# 2  chevron phillips chemical co . , lp ( hplc 04 ...
# 3                         get your viagr $ a today !
# 4                                      may wellheads
#
#                                                Email  Label
# 0  the deals are in and the ticket numbers are ja...      0
# 1  daren , i am trying to process two invoices fr...      0
# 2  darren -\nplease advise on the 04 / 01 price f...      0
# 3                                                NaN      1
# 4  david here is the other side of the coin . the...      0

# %%
#Drop NA Values
#df_training.columns[df_training.isna().any()]
df_training = df_training.dropna()
df_test = df_test.dropna()

df_training.columns[df_training.isna().any()]
# Out:
# Index([], dtype='object')

# %%
df_test.groupby("Label").describe()
# Out:
#       Subject                                       Email         \
#         count unique                       top freq count unique
# Label
# 0         100     98           oasis on - line    2   100    100
# 1          90     90  wow , superfast delivery    1    90     88
#
#
#                                                      top freq
# Label
# 0      the deals are in and the ticket numbers are ja...    1
# 1                               click here to be removed    3

# %%
#Retrieving my train and test data set
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(df_training.drop("Label", axis="columns"), df_training.Label, test_size=0.2)

X_train = df_training.drop("Label", axis="columns")
X_test = df_test.drop("Label", axis="columns")
y_train = df_training["Label"]
y_test = df_test["Label"]

print(len(X_train))
print(len(X_test))
# Out:
# 192
# 190

# %%
X_train_encoded = X_train["Subject"] + " "  + X_train["Email"]
X_test_encoded = X_test["Subject"] + " "  + X_test["Email"]

# %%
from sklearn.pipeline import Pipeline

classifier = Pipeline([
    ("vectorizer", CountVectorizer()),
    ("nb", MultinomialNB())
])

# Manually setting the parameters to your classifier
classifier.set_params(
    vectorizer__ngram_range=(1, 2),
    vectorizer__max_df=0.6,
    vectorizer__min_df=1,
    nb__alpha=1.0
)

classifier.fit(X_train_encoded, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(max_df=0.6, ngram_range=(1, 2))),
#                 ('nb', MultinomialNB())])

# %%
classifier.score(X_test_encoded, y_test)
# Out:
# 0.9578947368421052

# %%
prediction = classifier.predict(X_test_encoded)
prediction_label = ["spam" if x == 1 else "ham" for x in prediction]
prediction_label[:3]
# Out:
# ['ham', 'ham', 'ham']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_prediction = prediction

accuracy = accuracy_score(y_test, y_prediction)
precision = precision_score(y_test, y_prediction, pos_label=1)
recall = recall_score(y_test, y_prediction, pos_label=1) 
f_score = f1_score(y_test, y_prediction, pos_label=1)

print("For Naive Bayes\n")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F-score: {f_score}")
# Out:
# For Naive Bayes
#
# Accuracy: 0.9578947368421052
# Precision: 0.9555555555555556
# Recall: 0.9555555555555556
# F-score: 0.9555555555555556

# %%
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, prediction)

plt.figure(figsize = (6,3))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Prediction")
plt.ylabel("Truth")
# Out:
# Text(45.722222222222214, 0.5, 'Truth')
